# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from scipy import integrate
from scipy import linalg
from scipy import interpolate
from sklearn import gaussian_process as gp
from mpl_toolkits.mplot3d import Axes3D
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
import operator
from functools import reduce
from functools import partial
from timeit import default_timer
from utilities3 import *
from Adam import Adam
from deeponet import *
from util import *

# %%
def newplot(loader,model,name):
    fig = plt.figure(figsize=(8,3.5),dpi=150)
    ax1 = fig.add_subplot(121)
    plt.xlabel('$x$')
    plt.ylabel('$u$')
    ax2 = fig.add_subplot(122)
    plt.xlabel('$x$')
    plt.ylabel('$u-u_p$')
    i = 0
    with torch.no_grad():
        for x, l, y in loader:
            x, l, y = x.cuda(), l.cuda(), y.cuda()
            out = model(x,l).view(-1)
            gt = y.view(-1)
            resi = out-gt
            if i==0:
                ax1.plot(np.linspace(0,1,out.shape[-1]),out.cpu(),c='b',label='predictive value')
                ax1.plot(np.linspace(0,1,out.shape[-1]),gt.cpu(),c='y',label='ground truth')
                i += 1
            else:
                ax1.plot(np.linspace(0,1,out.shape[-1]),out.cpu(),c='b')
                ax1.plot(np.linspace(0,1,out.shape[-1]),gt.cpu(),c='y')
            ax2.plot(np.linspace(0,1,out.shape[-1]),resi.cpu(),c='tab:blue')
    ax1.grid()
    ax1.legend()
    ax2.grid()
    plt.tight_layout()
    plt.show()
    fig.savefig("img/"+name+".png")
    
def testmodel(model,loader,myloss = LpLoss(size_average=False)):
    test_mse = 0
    test_l2 = 0
    with torch.no_grad():
        for x, l, y in loader:
            x, l, y = x.cuda(), l.cuda(), y.cuda()
            out = model(x,l).view(-1)
            mse = F.mse_loss(out.view(1, -1), y.view(1, -1), reduction='mean')
            l2 = myloss(out.view(1, -1), y.view(1, -1))
            test_mse += mse.item()
            test_l2 += l2.item()
        test_mse /= len(loader)
        test_l2 /= ntest
        print('test error: L2 =',test_l2,'MSE =',test_mse)

# %%
f_train = generate(length_scale=0.2)
f_test_1 = generate(samples=100,length_scale=0.2)
f_test_2 = generate(samples=100,length_scale=2)
f_test_3 = generate(samples=100,length_scale=0.2,A=10)
f_test_4 = generate(samples=100,length_scale=2,A=10)
f_test = np.concatenate((f_test_1,f_test_2))
f_test = np.concatenate((f_test,f_test_3))
f_test = np.concatenate((f_test,f_test_4))
u_train = FD_1(f_train,-(1/2**6),1,0,0,0)
u_test = FD_1(f_test,-(1/2**6),1,0,0,0)
f_0 = np.zeros_like(f_train)+1
u_0 = FD_1(f_0,-(1/2**6),1,0,0,0)
f_new = 1*f_train+10
u_new = 1*u_train+10*u_0
f_aug = np.concatenate((f_train,f_new))
u_aug = np.concatenate((u_train,u_new))

f_train = f_train[:,::10]
u_train = u_train[:,::10]
f_aug = f_aug[:,::10]
u_aug = u_aug[:,::10]
f_test = f_test[:,::10]
u_test = u_test[:,::10]

dim = f_train.shape[-1]
grid = np.linspace(0, 1, dim)

N = f_train.shape[0]
loc = np.zeros((N,1))
res = np.zeros((N,1))
for i in range(N):
    j = np.random.randint(dim)
    loc[i,0] = grid[j]
    res[i,0] = u_train[i,j]
    
f_train = torch.Tensor(f_train)
loc_train = torch.Tensor(loc)
u_train = torch.Tensor(res)    
train_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(f_train, loc_train, u_train), batch_size=100, shuffle=True)

N = f_aug.shape[0]
loc = np.zeros((N,1))
res = np.zeros((N,1))
for i in range(N):
    j = np.random.randint(dim)
    loc[i,0] = grid[j]
    res[i,0] = u_aug[i,j]

f_aug = torch.Tensor(f_aug)
loc_aug = torch.Tensor(loc)
u_aug = torch.Tensor(res)
aug_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(f_aug, loc_aug, u_aug), batch_size=100, shuffle=True)

dim = f_test.shape[-1]
N = f_test.shape[0]*dim
loc = np.zeros((N,1))
res = np.zeros((N,1))
f = np.zeros((N,dim))
for i in range(N):
    f[i] = f_test[i//dim]
    loc[i,0] = grid[i%dim]
    res[i,0] = u_test[i//dim,i%dim]
f_test = torch.Tensor(f)
loc = torch.Tensor(loc)
res = torch.Tensor(res)
test_1_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(f_test[:100*dim], loc[:100*dim], res[:100*dim]), batch_size=dim, shuffle=False)
test_2_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(f_test[100*dim:200*dim], loc[100*dim:200*dim], res[100*dim:200*dim]), batch_size=dim, shuffle=False)
test_3_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(f_test[200*dim:300*dim], loc[200*dim:300*dim], res[200*dim:300*dim]), batch_size=dim, shuffle=False)
test_4_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(f_test[300*dim:], loc[300*dim:], res[300*dim:]), batch_size=dim, shuffle=False)

# %%
ntrain = 1000
ntest = 100
naug = 2000
batch_size = 100
learning_rate = 0.001
epochs = 600
step_size = 50
gamma = 0.5

model = DeepONet(dim,1).cuda()
optimizer = Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
myloss = LpLoss(size_average=False)
for ep in range(epochs):
    model.train()
    train_mse = 0
    for x, l, y in train_loader:
        x, l, y = x.cuda(), l.cuda(), y.cuda()
        optimizer.zero_grad()
        out = model(x,l)
        mse = F.mse_loss(out.view(batch_size, -1), y.view(batch_size, -1), reduction='mean')
        mse.backward()
        optimizer.step()
        train_mse += mse.item()
    scheduler.step()
    train_mse /= len(train_loader)
    print('\repoch {:d}/{:d} MSE = {:.10f}'.format(ep+1,epochs,train_mse), end='', flush=True)
    
#torch.save(model,'model/deeponet3_1')
# Out:
# epoch 600/600 MSE = 0.0007925939

# %%
#测试
testmodel(model,test_1_loader)
testmodel(model,test_2_loader)
testmodel(model,test_3_loader)
testmodel(model,test_4_loader)

#画图
newplot(test_1_loader,model,'deeponet_spde_base_1')
newplot(test_2_loader,model,'deeponet_spde_base_2')
newplot(test_3_loader,model,'deeponet_spde_base_3')
newplot(test_4_loader,model,'deeponet_spde_base_4')
# Out:
# test error: L2 = 0.19136308647692205 MSE = 0.004202302804478677
# test error: L2 = 0.16193506985902786 MSE = 0.007328446835635986
# test error: L2 = 0.15208661213517188 MSE = 0.7134097558259964
# test error: L2 = 0.1514570438861847 MSE = 0.7129535871744156

# %%
model = DeepONet(dim,1).cuda()
optimizer = Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

for ep in range(epochs):
    model.train()
    train_mse = 0
    for x, l, y in aug_loader:
        x, l, y = x.cuda(), l.cuda(), y.cuda()
        optimizer.zero_grad()
        out = model(x,l)
        mse = F.mse_loss(out.view(batch_size, -1), y.view(batch_size, -1), reduction='mean')
        mse.backward()
        optimizer.step()
        train_mse += mse.item()
    scheduler.step()
    train_mse /= len(aug_loader)
    print('\repoch {:d}/{:d} MSE = {:.10f}'.format(ep+1,epochs,train_mse), end='', flush=True)
    
#torch.save(model,'model/deeponet3_2')
# Out:
# epoch 600/600 MSE = 0.0025734085

# %%
#测试
testmodel(model,test_1_loader)
testmodel(model,test_2_loader)
testmodel(model,test_3_loader)
testmodel(model,test_4_loader)

#画图
newplot(test_1_loader,model,'deeponet_spde_pgda_1')
newplot(test_2_loader,model,'deeponet_spde_pgda_2')
newplot(test_3_loader,model,'deeponet_spde_pgda_3')
newplot(test_4_loader,model,'deeponet_spde_pgda_4')
# Out:
# test error: L2 = 0.21813351007178425 MSE = 0.002530012945208
# test error: L2 = 0.0542062166845426 MSE = 0.00019839716332626268
# test error: L2 = 0.011046758187003434 MSE = 0.004039311510277912
# test error: L2 = 0.006905200723558665 MSE = 0.0014790050277952104
